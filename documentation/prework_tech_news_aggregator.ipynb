# %% [markdown]
# # Αυτό είναι ενα POC prework των δεδομένων πριν την αυτοματοποίηση.
# ## Παίρνουμε δεδομένα από το Hacker News API (Firebase).

# %% [markdown]
# ### Το HN API είναι read-only JSON endpoints.
#
# ### Base URL
#
#     https://hacker-news.firebaseio.com/v0/
#
# ### Top stories IDs:
#     https://hacker-news.firebaseio.com/v0/topstories.json
#
# ### Details για ένα story (με id):
#     https://hacker-news.firebaseio.com/v0/item/<ID>.json
#
# ### Δεν θελει API key. Απλά HTTP GET.
#
# ### Σημείωση:
# ### Το ranking των topstories ορίζεται από τον αλγόριθμο του Hacker News, ο οποίος λαμβάνει υπόψη κυρίως:
#
#     - score (upvotes)
#
#     - age/time (πόσο πρόσφατο είναι)
#
#     - engagement / activity

# %% [markdown]
# # 1)Extract:
# ##### Παίρνω details για τα πρώτα 20 stories από το topstories endpoint. (κρατάμε μόνο type = story)

# %%
# !pip -q install requests pandas

# %%
import time
import requests
from typing import Optional, Dict, List, Any

BASE = "https://hacker-news.firebaseio.com/v0"
session = requests.Session()

def fetch_item(item_id: int) -> Optional[Dict[str, Any]]:
    r = session.get(f"{BASE}/item/{item_id}.json", timeout=30)
    r.raise_for_status()
    return r.json()

def fetch_top_ids() -> List[int]:
    r = session.get(f"{BASE}/topstories.json", timeout=30)
    r.raise_for_status()
    return r.json()

def top_20_stories_only(pause: float = 0.05) -> List[Dict[str, Any]]:
    top_ids = fetch_top_ids()  # up to 500

    stories: List[Dict[str, Any]] = []

    for item_id in top_ids:
        data = fetch_item(item_id)
        time.sleep(pause)

        if not data:
            continue


        if data.get("type") != "story":
            continue

        # πεταω dead/deleted
        if data.get("deleted") or data.get("dead"):
            continue

        stories.append(data)

        # stop όταν συμπληρωσουμε 20
        if len(stories) == 20:
            break

    return stories

top20 = top_20_stories_only()
[(s["id"], s.get("score"), s.get("title")) for s in top20[:5]]
# Out:
# [(46564696, 70, 'Allow me to introduce, the Citroen C15'),
#  (46565132,
#   34,
#   'A Eulogy for Dark Sky, a Data Visualization Masterpiece (2023)'),
#  (46560445,
#   521,
#   '“Erdos problem #728 was solved more or less autonomously by AI”'),
#  (46524379, 190, 'Changes to Android Open Source Project'),
#  (46565281, 37, 'All my new code will be closed-source from now on')]

# %%
### Σε Dataframe:
import pandas as pd

df_top20 = pd.DataFrame(top20)

cols = ["id", "score", "title", "url", "type", "by", "time", "descendants"]
df_top20 = df_top20.reindex(columns=cols)

df_top20
# Out:
#           id  score                                              title  \
# 0   46564696     70             Allow me to introduce, the Citroen C15
# 1   46565132     34  A Eulogy for Dark Sky, a Data Visualization Ma...
# 2   46560445    521  “Erdos problem #728 was solved more or less au...
# 3   46524379    190             Changes to Android Open Source Project
# 4   46565281     37  All my new code will be closed-source from now on
# 5   46511555    158  Greenland sharks maintain vision for centuries...
# 6   46564762     13  New information extracted from Snowden PDFs th...
# 7   46557489    281                 JavaScript Demos in 140 Characters
# 8   46556695    321                   How Markdown took over the world
# 9   46560217    172              Start your meetings at 5 minutes past
# 10  46562790    223                               Oh My Zsh adds bloat
# 11  46506261     14  Ask HN: What's a standard way for apps to requ...
# 12  46558148    251            RTX 5090 and Raspberry Pi: Can it game?
# 13  46489514    480                 How will the miracle happen today?
# 14  46497443     14  Diving into Qualcomm's Upcoming Adreno X2 GPU ...
# 15  46473897     48  Alien: Braun Aromaster KF 20 Coffee Makers (2012)
# 16  46557879    137         Show HN: Rocket Launch and Orbit Simulator
# 17  46557029    277              Show HN: Scroll Wikipedia like TikTok
# 18  46564618     46  I got paid minimum wage to solve an impossible...
# 19  46555760    576                  Cloudflare CEO on the Italy fines
#
#                                                   url   type            by  \
# 0   https://eupolicy.social/@jmaris/11586059523809...  story   colinprince
# 1   https://nightingaledvs.com/dark-sky-weather-da...  story      skadamat
# 2      https://mathstodon.xyz/@tao/115855840223258103  story         cod1r
# 3                         https://source.android.com/  story  TechTechTech
# 4   https://twitter.com/MarcJSchmidt/status/200968...  story      mvelbaum
# 5   https://phys.org/news/2026-01-eye-greenland-sh...  story     pseudolus
# 6   https://libroot.org/posts/going-through-snowde...  story       libroot
# 7                            https://beta.dwitter.net  story   themanmaran
# 8   https://www.anildash.com/2026/01/09/how-markdo...  story           zdw
# 9   https://philipotoole.com/start-your-meetings-a...  story       otoolep
# 10                https://rushter.com/blog/zsh-shell/  story           fla
# 11                                                NaN  story        nvader
# 12  https://scottjg.com/posts/2026-01-08-crappy-co...  story       scottjg
# 13  https://kk.org/thetechnium/how-will-the-miracl...  story           zdw
# 14  https://chipsandcheese.com/p/diving-into-qualc...  story       rbanffy
# 15  http://alienexplorations.blogspot.com/1979/05/...  story          exvi
# 16                      https://www.donutthejedi.com/  story  donutthejedi
# 17                              https://quack.sdan.io  story          sdan
# 18  https://tiespetersen.substack.com/p/i-got-paid...  story   thunderbong
# 19  https://twitter.com/eastdakota/status/20096549...  story       sidcool
#
#           time  descendants
# 0   1768043535           35
# 1   1768047800           18
# 2   1767998355          284
# 3   1767778546          112
# 4   1768049485           33
# 5   1767703492           62
# 6   1768044239            4
# 7   1767984510           53
# 8   1767981140          246
# 9   1767997143          157
# 10  1768019732          214
# 11  1767653474            6
# 12  1767987227           99
# 13  1767544333          241
# 14  1767611408           10
# 15  1767427721           13
# 16  1767986121           35
# 17  1767982516           69
# 18  1768042408           17
# 19  1767977208          871

# %% [markdown]
# # 2)Transform:

# %%
# Unix time σε datetime
df_top20["published_at"] = pd.to_datetime(df_top20["time"], unit="s", utc=True)
df_top20[["id", "time", "published_at"]].head(5)
# Out:
#          id        time              published_at
# 0  46564696  1768043535 2026-01-10 11:12:15+00:00
# 1  46565132  1768047800 2026-01-10 12:23:20+00:00
# 2  46560445  1767998355 2026-01-09 22:39:15+00:00
# 3  46524379  1767778546 2026-01-07 09:35:46+00:00
# 4  46565281  1768049485 2026-01-10 12:51:25+00:00

# %%
# Domain από URL
from urllib.parse import urlparse
import numpy as np

def extract_domain(u):
    # χειρισμός None/NaN/non-string/empty
    if not isinstance(u, str) or u.strip() == "":
        return None
    
    parsed = urlparse(u.strip())
    host = parsed.netloc.lower()

    # αν το url είναι "news.ycombinator.com/item?id=..." χωρίς scheme,
    # urlparse μπορεί να το διαβάσει περίεργα. Καλύπτουμε κι αυτό:
    if host == "" and "://" not in u:
        parsed2 = urlparse("https://" + u.strip())
        host = parsed2.netloc.lower()

    # αφαιρούμε "www."
    if host.startswith("www."):
        host = host[4:]

    return host or None

df_top20["domain"] = df_top20["url"].apply(extract_domain)

df_top20[["id", "title", "url", "domain"]].head(10)
# Out:
#          id                                              title  \
# 0  46564696             Allow me to introduce, the Citroen C15
# 1  46565132  A Eulogy for Dark Sky, a Data Visualization Ma...
# 2  46560445  “Erdos problem #728 was solved more or less au...
# 3  46524379             Changes to Android Open Source Project
# 4  46565281  All my new code will be closed-source from now on
# 5  46511555  Greenland sharks maintain vision for centuries...
# 6  46564762  New information extracted from Snowden PDFs th...
# 7  46557489                 JavaScript Demos in 140 Characters
# 8  46556695                   How Markdown took over the world
# 9  46560217              Start your meetings at 5 minutes past
#
#                                                  url              domain
# 0  https://eupolicy.social/@jmaris/11586059523809...     eupolicy.social
# 1  https://nightingaledvs.com/dark-sky-weather-da...  nightingaledvs.com
# 2     https://mathstodon.xyz/@tao/115855840223258103      mathstodon.xyz
# 3                        https://source.android.com/  source.android.com
# 4  https://twitter.com/MarcJSchmidt/status/200968...         twitter.com
# 5  https://phys.org/news/2026-01-eye-greenland-sh...            phys.org
# 6  https://libroot.org/posts/going-through-snowde...         libroot.org
# 7                           https://beta.dwitter.net    beta.dwitter.net
# 8  https://www.anildash.com/2026/01/09/how-markdo...        anildash.com
# 9  https://philipotoole.com/start-your-meetings-a...    philipotoole.com

# %%
# Missing values check
missing = df_top20[["score","title","url","domain","by","time","descendants"]].isna().sum()
missing
# Out:
# score          0
# title          0
# url            1
# domain         1
# by             0
# time           0
# descendants    0
# dtype: int64

# %%
# Duplicates check
dupe_ids = df_top20["id"].duplicated().sum()
dupe_ids
# Out:
# 0

# %%
# Τύποι δεδομένων για την Postgres
df_top20.dtypes
# Out:
# id                            int64
# score                         int64
# title                        object
# url                          object
# type                         object
# by                           object
# time                          int64
# descendants                   int64
# published_at    datetime64[ns, UTC]
# domain                       object
# dtype: object

# %%
# sanity checks
checks = {
    "rows": len(df_top20),
    "unique_ids": df_top20["id"].nunique(),
    "min_score": df_top20["score"].min(skipna=True),
    "max_score": df_top20["score"].max(skipna=True),
    "missing_url": int(df_top20["url"].isna().sum()),
    "missing_descendants": int(df_top20["descendants"].isna().sum()),
    "types": df_top20["type"].value_counts(dropna=False).to_dict(),
}
checks
# Out:
# {'rows': 20,
#  'unique_ids': 20,
#  'min_score': 13,
#  'max_score': 576,
#  'missing_url': 1,
#  'missing_descendants': 0,
#  'types': {'story': 20}}

# %%
# Τελική μορφή στηλών
final_cols = ["id", "score", "title", "domain", "url", "type", "by", "published_at", "descendants"]
df_final = df_top20.reindex(columns=final_cols).copy()

df_final.head()
# Out:
#          id  score                                              title  \
# 0  46564696     70             Allow me to introduce, the Citroen C15
# 1  46565132     34  A Eulogy for Dark Sky, a Data Visualization Ma...
# 2  46560445    521  “Erdos problem #728 was solved more or less au...
# 3  46524379    190             Changes to Android Open Source Project
# 4  46565281     37  All my new code will be closed-source from now on
#
#                domain                                                url  \
# 0     eupolicy.social  https://eupolicy.social/@jmaris/11586059523809...
# 1  nightingaledvs.com  https://nightingaledvs.com/dark-sky-weather-da...
# 2      mathstodon.xyz     https://mathstodon.xyz/@tao/115855840223258103
# 3  source.android.com                        https://source.android.com/
# 4         twitter.com  https://twitter.com/MarcJSchmidt/status/200968...
#
#     type            by              published_at  descendants
# 0  story   colinprince 2026-01-10 11:12:15+00:00           35
# 1  story      skadamat 2026-01-10 12:23:20+00:00           18
# 2  story         cod1r 2026-01-09 22:39:15+00:00          284
# 3  story  TechTechTech 2026-01-07 09:35:46+00:00          112
# 4  story      mvelbaum 2026-01-10 12:51:25+00:00           33

# %%
# Naming για Postgres
df_pg = df_final.rename(columns={
    "id": "story_id",
    "by": "author",
    "descendants": "comment_count",
    "published_at": "published_at_utc",
})

df_pg.head()
# Out:
#    story_id  score                                              title  \
# 0  46564696     70             Allow me to introduce, the Citroen C15
# 1  46565132     34  A Eulogy for Dark Sky, a Data Visualization Ma...
# 2  46560445    521  “Erdos problem #728 was solved more or less au...
# 3  46524379    190             Changes to Android Open Source Project
# 4  46565281     37  All my new code will be closed-source from now on
#
#                domain                                                url  \
# 0     eupolicy.social  https://eupolicy.social/@jmaris/11586059523809...
# 1  nightingaledvs.com  https://nightingaledvs.com/dark-sky-weather-da...
# 2      mathstodon.xyz     https://mathstodon.xyz/@tao/115855840223258103
# 3  source.android.com                        https://source.android.com/
# 4         twitter.com  https://twitter.com/MarcJSchmidt/status/200968...
#
#     type        author          published_at_utc  comment_count
# 0  story   colinprince 2026-01-10 11:12:15+00:00             35
# 1  story      skadamat 2026-01-10 12:23:20+00:00             18
# 2  story         cod1r 2026-01-09 22:39:15+00:00            284
# 3  story  TechTechTech 2026-01-07 09:35:46+00:00            112
# 4  story      mvelbaum 2026-01-10 12:51:25+00:00             33

# %% [markdown]
# # 3)Load:

# %%
# !pip -q install psycopg2-binary

# %%
# Connection
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=15432,
    dbname="hn_db",
    user="hn_user",
    password="hn_pass"
)

with conn.cursor() as cur:
    cur.execute("SELECT now(), current_database(), current_user;")
    print(cur.fetchone())
# Out:
# (datetime.datetime(2026, 1, 10, 18, 47, 48, 108406, tzinfo=datetime.timezone.utc), 'hn_db', 'hn_user')

# %%
from psycopg2.extras import execute_batch

# 1) Create table (just in case)
create_sql = """
CREATE TABLE IF NOT EXISTS news_archive (
  story_id BIGINT PRIMARY KEY,
  title TEXT,
  url TEXT,
  domain TEXT,
  author TEXT,
  published_at_utc TIMESTAMPTZ,
  score INTEGER,
  comment_count INTEGER,
  first_seen_at TIMESTAMPTZ NOT NULL DEFAULT NOW(),
  last_seen_at  TIMESTAMPTZ NOT NULL DEFAULT NOW()
);
"""

with conn.cursor() as cur:
    cur.execute(create_sql)
conn.commit()

# 2) UPSERT:
# - first_seen_at: set only on INSERT (NOW())
# - last_seen_at: updated every run (NOW())
upsert_sql = """
INSERT INTO news_archive (
  story_id, title, url, domain, author, published_at_utc, score, comment_count,
  first_seen_at, last_seen_at
)
VALUES (
  %(story_id)s, %(title)s, %(url)s, %(domain)s, %(author)s, %(published_at_utc)s,
  %(score)s, %(comment_count)s,
  NOW(), NOW()
)
ON CONFLICT (story_id)
DO UPDATE SET
  title = EXCLUDED.title,
  url = EXCLUDED.url,
  domain = EXCLUDED.domain,
  author = EXCLUDED.author,
  published_at_utc = EXCLUDED.published_at_utc,
  score = EXCLUDED.score,
  comment_count = EXCLUDED.comment_count,
  last_seen_at = NOW();
"""

records = df_pg.to_dict(orient="records")

with conn.cursor() as cur:
    execute_batch(cur, upsert_sql, records, page_size=200)
conn.commit()

print(f"Loaded/Upserted rows: {len(records)}")
# Out:
# Loaded/Upserted rows: 20

# %%
# Data check
pd.read_sql("SELECT * FROM news_archive ORDER BY last_seen_at DESC;", conn)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_88936\1902506266.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM news_archive ORDER BY last_seen_at DESC;", conn)
#     story_id                                              title  \
# 0   46564696             Allow me to introduce, the Citroen C15
# 1   46565132  A Eulogy for Dark Sky, a Data Visualization Ma...
# 2   46560445  “Erdos problem #728 was solved more or less au...
# 3   46524379             Changes to Android Open Source Project
# 4   46565281  All my new code will be closed-source from now on
# 5   46511555  Greenland sharks maintain vision for centuries...
# 6   46564762  New information extracted from Snowden PDFs th...
# 7   46557489                 JavaScript Demos in 140 Characters
# 8   46556695                   How Markdown took over the world
# 9   46560217              Start your meetings at 5 minutes past
# 10  46562790                               Oh My Zsh adds bloat
# 11  46506261  Ask HN: What's a standard way for apps to requ...
# 12  46558148            RTX 5090 and Raspberry Pi: Can it game?
# 13  46489514                 How will the miracle happen today?
# 14  46497443  Diving into Qualcomm's Upcoming Adreno X2 GPU ...
# 15  46473897  Alien: Braun Aromaster KF 20 Coffee Makers (2012)
# 16  46557879         Show HN: Rocket Launch and Orbit Simulator
# 17  46557029              Show HN: Scroll Wikipedia like TikTok
# 18  46564618  I got paid minimum wage to solve an impossible...
# 19  46555760                  Cloudflare CEO on the Italy fines
#
#                                                   url  \
# 0   https://eupolicy.social/@jmaris/11586059523809...
# 1   https://nightingaledvs.com/dark-sky-weather-da...
# 2      https://mathstodon.xyz/@tao/115855840223258103
# 3                         https://source.android.com/
# 4   https://twitter.com/MarcJSchmidt/status/200968...
# 5   https://phys.org/news/2026-01-eye-greenland-sh...
# 6   https://libroot.org/posts/going-through-snowde...
# 7                            https://beta.dwitter.net
# 8   https://www.anildash.com/2026/01/09/how-markdo...
# 9   https://philipotoole.com/start-your-meetings-a...
# 10                https://rushter.com/blog/zsh-shell/
# 11                                                NaN
# 12  https://scottjg.com/posts/2026-01-08-crappy-co...
# 13  https://kk.org/thetechnium/how-will-the-miracl...
# 14  https://chipsandcheese.com/p/diving-into-qualc...
# 15  http://alienexplorations.blogspot.com/1979/05/...
# 16                      https://www.donutthejedi.com/
# 17                              https://quack.sdan.io
# 18  https://tiespetersen.substack.com/p/i-got-paid...
# 19  https://twitter.com/eastdakota/status/20096549...
#
#                             domain        author          published_at_utc  \
# 0                  eupolicy.social   colinprince 2026-01-10 11:12:15+00:00
# 1               nightingaledvs.com      skadamat 2026-01-10 12:23:20+00:00
# 2                   mathstodon.xyz         cod1r 2026-01-09 22:39:15+00:00
# 3               source.android.com  TechTechTech 2026-01-07 09:35:46+00:00
# 4                      twitter.com      mvelbaum 2026-01-10 12:51:25+00:00
# 5                         phys.org     pseudolus 2026-01-06 12:44:52+00:00
# 6                      libroot.org       libroot 2026-01-10 11:23:59+00:00
# 7                 beta.dwitter.net   themanmaran 2026-01-09 18:48:30+00:00
# 8                     anildash.com           zdw 2026-01-09 17:52:20+00:00
# 9                 philipotoole.com       otoolep 2026-01-09 22:19:03+00:00
# 10                     rushter.com           fla 2026-01-10 04:35:32+00:00
# 11                            None        nvader 2026-01-05 22:51:14+00:00
# 12                     scottjg.com       scottjg 2026-01-09 19:33:47+00:00
# 13                          kk.org           zdw 2026-01-04 16:32:13+00:00
# 14              chipsandcheese.com       rbanffy 2026-01-05 11:10:08+00:00
# 15  alienexplorations.blogspot.com          exvi 2026-01-03 08:08:41+00:00
# 16                donutthejedi.com  donutthejedi 2026-01-09 19:15:21+00:00
# 17                   quack.sdan.io          sdan 2026-01-09 18:15:16+00:00
# 18       tiespetersen.substack.com   thunderbong 2026-01-10 10:53:28+00:00
# 19                     twitter.com       sidcool 2026-01-09 16:46:48+00:00
#
#     score  comment_count                    first_seen_at  \
# 0      70             35 2026-01-10 18:47:51.061978+00:00
# 1      34             18 2026-01-10 18:47:51.061978+00:00
# 2     521            284 2026-01-10 18:47:51.061978+00:00
# 3     190            112 2026-01-10 18:47:51.061978+00:00
# 4      37             33 2026-01-10 18:47:51.061978+00:00
# 5     158             62 2026-01-10 18:47:51.061978+00:00
# 6      13              4 2026-01-10 18:47:51.061978+00:00
# 7     281             53 2026-01-10 18:47:51.061978+00:00
# 8     321            246 2026-01-10 18:47:51.061978+00:00
# 9     172            157 2026-01-10 18:47:51.061978+00:00
# 10    223            214 2026-01-10 18:47:51.061978+00:00
# 11     14              6 2026-01-10 18:47:51.061978+00:00
# 12    251             99 2026-01-10 18:47:51.061978+00:00
# 13    480            241 2026-01-10 18:47:51.061978+00:00
# 14     14             10 2026-01-10 18:47:51.061978+00:00
# 15     48             13 2026-01-10 18:47:51.061978+00:00
# 16    137             35 2026-01-10 18:47:51.061978+00:00
# 17    277             69 2026-01-10 18:47:51.061978+00:00
# 18     46             17 2026-01-10 18:47:51.061978+00:00
# 19    576            871 2026-01-10 18:47:51.061978+00:00
#
#                        last_seen_at
# 0  2026-01-10 18:47:51.061978+00:00
# 1  2026-01-10 18:47:51.061978+00:00
# 2  2026-01-10 18:47:51.061978+00:00
# 3  2026-01-10 18:47:51.061978+00:00
# 4  2026-01-10 18:47:51.061978+00:00
# 5  2026-01-10 18:47:51.061978+00:00
# 6  2026-01-10 18:47:51.061978+00:00
# 7  2026-01-10 18:47:51.061978+00:00
# 8  2026-01-10 18:47:51.061978+00:00
# 9  2026-01-10 18:47:51.061978+00:00
# 10 2026-01-10 18:47:51.061978+00:00
# 11 2026-01-10 18:47:51.061978+00:00
# 12 2026-01-10 18:47:51.061978+00:00
# 13 2026-01-10 18:47:51.061978+00:00
# 14 2026-01-10 18:47:51.061978+00:00
# 15 2026-01-10 18:47:51.061978+00:00
# 16 2026-01-10 18:47:51.061978+00:00
# 17 2026-01-10 18:47:51.061978+00:00
# 18 2026-01-10 18:47:51.061978+00:00
# 19 2026-01-10 18:47:51.061978+00:00
